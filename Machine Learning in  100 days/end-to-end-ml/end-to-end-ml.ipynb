# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
# Steps:
# 1> Preprocess +EDA + Feature Selection
# 2> Extract input and output cols
# 3> Scale the values 
# 4> Trai test Split
# 5> Evaluate the model/model selection
# 6> Deploy the model

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X =  df.iloc[:,0:2]
y =  df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
train_test_split(X,y,test_size=0.1)
# Out:
# [    cgpa     iq
#  27   6.0  124.0
#  74   6.7  154.0
#  49   5.4  135.0
#  97   6.7  182.0
#  12   5.4  139.0
#  ..   ...    ...
#  13   6.4  116.0
#  76   4.9  155.0
#  52   7.0  175.0
#  0    6.8  123.0
#  79   6.5   90.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  84   5.7  169.0
#  55   7.8  114.0
#  65   8.1  166.0
#  7    5.0   63.0
#  38   6.5  160.0
#  88   4.4  149.0
#  44   7.5   61.0
#  61   7.3  137.0
#  28   5.2   90.0
#  3    7.4  132.0,
#  27    1
#  74    1
#  49    0
#  97    1
#  12    0
#       ..
#  13    1
#  76    0
#  52    1
#  0     1
#  79    1
#  Name: placement, Length: 90, dtype: int64,
#  84    0
#  55    1
#  65    1
#  7     0
#  38    1
#  88    0
#  44    1
#  61    1
#  28    0
#  3     1
#  Name: placement, dtype: int64]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 75   4.8  169.0
# 23   4.7   87.0
# 14   6.1  103.0
# 66   6.9   96.0
# 4    5.8  142.0
# ..   ...    ...
# 18   4.0  100.0
# 45   6.0   66.0
# 87   5.7  132.0
# 30   7.6  128.0
# 51   4.8  141.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 75    0
# 23    0
# 14    0
# 66    1
# 4     0
#      ..
# 18    0
# 45    1
# 87    1
# 30    1
# 51    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 89   4.9  151.0
# 70   6.3  127.0
# 97   6.7  182.0
# 17   3.3  183.0
# 9    5.1   66.0
# 80   4.9  196.0
# 93   6.8  112.0
# 57   6.5  130.0
# 15   5.1  176.0
# 61   7.3  137.0

# %%
y_test
# Out:
# 89    0
# 70    1
# 97    1
# 17    0
# 9     0
# 80    0
# 93    1
# 57    1
# 15    0
# 61    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-1.08346026e+00,  1.22340957e+00],
#        [-1.17194613e+00, -8.70459311e-01],
#        [ 6.68559873e-02, -4.61899530e-01],
#        [ 7.74742912e-01, -6.40644434e-01],
#        [-1.98601609e-01,  5.33964936e-01],
#        [ 1.83657330e+00,  1.14680461e+00],
#        [ 6.68559873e-02, -1.02366923e+00],
#        [ 1.12868637e+00, -1.81525380e+00],
#        [-7.29516803e-01,  2.78615073e-01],
#        [-1.17194613e+00, -2.26977656e-03],
#        [-9.06488534e-01, -7.88747355e-02],
#        [ 8.63228777e-01,  1.37661948e+00],
#        [ 1.21717224e+00,  2.78615073e-01],
#        [-7.29516803e-01,  2.62783381e+00],
#        [-6.41030937e-01, -2.26977656e-03],
#        [ 8.63228777e-01, -1.45776400e+00],
#        [-2.87087475e-01,  5.59499922e-01],
#        [ 1.55341853e-01, -2.06549667e-01],
#        [ 3.32313584e-01, -1.29944708e-01],
#        [ 5.09285315e-01, -2.78047629e-02],
#        [ 1.74808743e+00, -1.07473920e+00],
#        [-2.16298782e-02, -4.87434517e-01],
#        [ 7.74742912e-01,  4.31824991e-01],
#        [-7.29516803e-01, -2.83154626e-01],
#        [-5.52545072e-01,  3.55220032e-01],
#        [-2.16298782e-02, -1.94292874e+00],
#        [-9.06488534e-01, -7.68319366e-01],
#        [ 1.12868637e+00, -1.29944708e-01],
#        [ 6.86257046e-01,  4.88001961e-02],
#        [-2.16298782e-02,  7.43351824e-02],
#        [ 3.32313584e-01,  5.08429950e-01],
#        [ 8.63228777e-01,  1.98945916e+00],
#        [-9.94974399e-01, -2.78047629e-02],
#        [ 6.68559873e-02,  8.91454744e-01],
#        [-9.94974399e-01, -1.53436896e+00],
#        [-9.94974399e-01,  8.65919758e-01],
#        [-2.16298782e-02,  7.12709840e-01],
#        [ 7.74742912e-01,  4.57359977e-01],
#        [-9.94974399e-01,  3.29685046e-01],
#        [-1.10115744e-01, -3.85294571e-01],
#        [ 4.20799450e-01, -2.14720863e+00],
#        [ 1.83657330e+00,  7.12709840e-01],
#        [-1.79134719e+00, -1.17687915e+00],
#        [ 1.30565811e+00,  9.42524717e-01],
#        [-7.29516803e-01, -7.93854352e-01],
#        [ 6.68559873e-02, -1.43222901e+00],
#        [-5.52545072e-01, -3.59759585e-01],
#        [-1.43740373e+00, -2.01953370e+00],
#        [ 1.57111570e+00, -1.81014681e-01],
#        [-5.52545072e-01,  4.57359977e-01],
#        [ 2.19051676e+00, -2.78047629e-02],
#        [ 4.20799450e-01, -7.93854352e-01],
#        [ 2.43827718e-01, -4.61899530e-01],
#        [ 2.01354503e+00,  1.19787458e+00],
#        [ 9.51714643e-01,  7.63779813e-01],
#        [ 8.63228777e-01,  4.57359977e-01],
#        [-8.18002668e-01,  1.76475128e-01],
#        [ 1.30565811e+00, -1.53436896e+00],
#        [ 1.39414397e+00, -8.19389339e-01],
#        [-5.52545072e-01, -1.81014681e-01],
#        [-7.29516803e-01,  1.01912968e+00],
#        [-1.52588959e+00,  2.01499414e+00],
#        [-1.08346026e+00,  1.07019965e+00],
#        [-1.08346026e+00, -2.32084653e-01],
#        [-6.41030937e-01, -1.81014681e-01],
#        [-2.23377652e+00,  2.85764869e+00],
#        [-1.98601609e-01,  1.14680461e+00],
#        [-2.87087475e-01,  4.82894963e-01],
#        [-2.87087475e-01,  1.22340957e+00],
#        [ 4.20799450e-01,  9.93594690e-01],
#        [ 1.30565811e+00,  2.27545100e-01],
#        [ 5.09285315e-01,  4.31824991e-01],
#        [-1.26043200e+00,  6.36104881e-01],
#        [ 2.43827718e-01,  1.76475128e-01],
#        [ 6.86257046e-01, -7.93854352e-01],
#        [-1.17194613e+00, -1.76418383e+00],
#        [ 1.12868637e+00, -8.95994298e-01],
#        [ 5.97771181e-01,  8.40384772e-01],
#        [ 9.51714643e-01, -1.86632378e+00],
#        [-1.43740373e+00,  7.12709840e-01],
#        [-1.87983306e+00, -3.08689612e-01],
#        [-9.06488534e-01, -1.48329898e+00],
#        [ 8.63228777e-01, -2.32084653e-01],
#        [ 6.86257046e-01,  5.08429950e-01],
#        [ 6.68559873e-02,  2.78615073e-01],
#        [-1.79134719e+00, -5.38504489e-01],
#        [-2.16298782e-02, -1.40669402e+00],
#        [-2.87087475e-01,  2.78615073e-01],
#        [ 1.39414397e+00,  1.76475128e-01],
#        [-1.08346026e+00,  5.08429950e-01]])

# %%
X_test
# Out:
# array([[-0.9949744 ,  0.76377981],
#        [ 0.24382772,  0.15094014],
#        [ 0.59777118,  1.55536439],
#        [-2.41074825,  1.58089937],
#        [-0.81800267, -1.40669402],
#        [-0.9949744 ,  1.9128542 ],
#        [ 0.68625705, -0.23208465],
#        [ 0.42079945,  0.2275451 ],
#        [-0.81800267,  1.40215447],
#        [ 1.12868637,  0.40629   ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
clf.predict(X_test)
# Out:
# array([0, 1, 1, 0, 0, 0, 1, 1, 0, 1])

# %%
y_test
# Out:
# 89    0
# 70    1
# 97    1
# 17    0
# 9     0
# 80    0
# 93    1
# 57    1
# 15    0
# 61    1
# Name: placement, dtype: int64

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
# !pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlxtend in c:\users\hp\appdata\roaming\python\python313\site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlxtend) (3.11.0)
# Requirement already satisfied: joblib>=1.5.2 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=9 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (2.7.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
from mlxtend.plotting import plot_decision_regions

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.08346026e+00,  1.22340957e+00],
#        [-1.17194613e+00, -8.70459311e-01],
#        [ 6.68559873e-02, -4.61899530e-01],
#        [ 7.74742912e-01, -6.40644434e-01],
#        [-1.98601609e-01,  5.33964936e-01],
#        [ 1.83657330e+00,  1.14680461e+00],
#        [ 6.68559873e-02, -1.02366923e+00],
#        [ 1.12868637e+00, -1.81525380e+00],
#        [-7.29516803e-01,  2.78615073e-01],
#        [-1.17194613e+00, -2.26977656e-03],
#        [-9.06488534e-01, -7.88747355e-02],
#        [ 8.63228777e-01,  1.37661948e+00],
#        [ 1.21717224e+00,  2.78615073e-01],
#        [-7.29516803e-01,  2.62783381e+00],
#        [-6.41030937e-01, -2.26977656e-03],
#        [ 8.63228777e-01, -1.45776400e+00],
#        [-2.87087475e-01,  5.59499922e-01],
#        [ 1.55341853e-01, -2.06549667e-01],
#        [ 3.32313584e-01, -1.29944708e-01],
#        [ 5.09285315e-01, -2.78047629e-02],
#        [ 1.74808743e+00, -1.07473920e+00],
#        [-2.16298782e-02, -4.87434517e-01],
#        [ 7.74742912e-01,  4.31824991e-01],
#        [-7.29516803e-01, -2.83154626e-01],
#        [-5.52545072e-01,  3.55220032e-01],
#        [-2.16298782e-02, -1.94292874e+00],
#        [-9.06488534e-01, -7.68319366e-01],
#        [ 1.12868637e+00, -1.29944708e-01],
#        [ 6.86257046e-01,  4.88001961e-02],
#        [-2.16298782e-02,  7.43351824e-02],
#        [ 3.32313584e-01,  5.08429950e-01],
#        [ 8.63228777e-01,  1.98945916e+00],
#        [-9.94974399e-01, -2.78047629e-02],
#        [ 6.68559873e-02,  8.91454744e-01],
#        [-9.94974399e-01, -1.53436896e+00],
#        [-9.94974399e-01,  8.65919758e-01],
#        [-2.16298782e-02,  7.12709840e-01],
#        [ 7.74742912e-01,  4.57359977e-01],
#        [-9.94974399e-01,  3.29685046e-01],
#        [-1.10115744e-01, -3.85294571e-01],
#        [ 4.20799450e-01, -2.14720863e+00],
#        [ 1.83657330e+00,  7.12709840e-01],
#        [-1.79134719e+00, -1.17687915e+00],
#        [ 1.30565811e+00,  9.42524717e-01],
#        [-7.29516803e-01, -7.93854352e-01],
#        [ 6.68559873e-02, -1.43222901e+00],
#        [-5.52545072e-01, -3.59759585e-01],
#        [-1.43740373e+00, -2.01953370e+00],
#        [ 1.57111570e+00, -1.81014681e-01],
#        [-5.52545072e-01,  4.57359977e-01],
#        [ 2.19051676e+00, -2.78047629e-02],
#        [ 4.20799450e-01, -7.93854352e-01],
#        [ 2.43827718e-01, -4.61899530e-01],
#        [ 2.01354503e+00,  1.19787458e+00],
#        [ 9.51714643e-01,  7.63779813e-01],
#        [ 8.63228777e-01,  4.57359977e-01],
#        [-8.18002668e-01,  1.76475128e-01],
#        [ 1.30565811e+00, -1.53436896e+00],
#        [ 1.39414397e+00, -8.19389339e-01],
#        [-5.52545072e-01, -1.81014681e-01],
#        [-7.29516803e-01,  1.01912968e+00],
#        [-1.52588959e+00,  2.01499414e+00],
#        [-1.08346026e+00,  1.07019965e+00],
#        [-1.08346026e+00, -2.32084653e-01],
#        [-6.41030937e-01, -1.81014681e-01],
#        [-2.23377652e+00,  2.85764869e+00],
#        [-1.98601609e-01,  1.14680461e+00],
#        [-2.87087475e-01,  4.82894963e-01],
#        [-2.87087475e-01,  1.22340957e+00],
#        [ 4.20799450e-01,  9.93594690e-01],
#        [ 1.30565811e+00,  2.27545100e-01],
#        [ 5.09285315e-01,  4.31824991e-01],
#        [-1.26043200e+00,  6.36104881e-01],
#        [ 2.43827718e-01,  1.76475128e-01],
#        [ 6.86257046e-01, -7.93854352e-01],
#        [-1.17194613e+00, -1.76418383e+00],
#        [ 1.12868637e+00, -8.95994298e-01],
#        [ 5.97771181e-01,  8.40384772e-01],
#        [ 9.51714643e-01, -1.86632378e+00],
#        [-1.43740373e+00,  7.12709840e-01],
#        [-1.87983306e+00, -3.08689612e-01],
#        [-9.06488534e-01, -1.48329898e+00],
#        [ 8.63228777e-01, -2.32084653e-01],
#        [ 6.86257046e-01,  5.08429950e-01],
#        [ 6.68559873e-02,  2.78615073e-01],
#        [-1.79134719e+00, -5.38504489e-01],
#        [-2.16298782e-02, -1.40669402e+00],
#        [-2.87087475e-01,  2.78615073e-01],
#        [ 1.39414397e+00,  1.76475128e-01],
#        [-1.08346026e+00,  5.08429950e-01]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.9949744 ,  0.76377981],
#        [ 0.24382772,  0.15094014],
#        [ 0.59777118,  1.55536439],
#        [-2.41074825,  1.58089937],
#        [-0.81800267, -1.40669402],
#        [-0.9949744 ,  1.9128542 ],
#        [ 0.68625705, -0.23208465],
#        [ 0.42079945,  0.2275451 ],
#        [-0.81800267,  1.40215447],
#        [ 1.12868637,  0.40629   ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
## Model training:
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
clf.predict(X_test)
# Out:
# array([0, 1, 1, 0, 0, 0, 1, 1, 0, 1])

# %%
y_test
# Out:
# 89    0
# 70    1
# 97    1
# 17    0
# 9     0
# 80    0
# 93    1
# 57    1
# 15    0
# 61    1
# Name: placement, dtype: int64

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
