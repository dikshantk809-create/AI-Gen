# %% [markdown]
# ## Standard library Overview

# %% [markdown]
# #### Pthon Standard Library is a vast collection of modules and packages that come bundled with Python,
# #### providing a wide range of fumctionalities out of the box.Here an overview of some of the most commonly
# #### using modules and packages in the python Standard Library.

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import  math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## randam:
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 8
# cherry

# %%
### File and Directory access
import os
print(os.getcwd())
# Out:
# c:\Users\HP\Desktop\AIML in 6 months '\05 - Importing, Creating Modules And Packages

# %%
os.mkdir('test_dir')

# %%
# High level operations on filer and collection of files
import shutil
shutil.copyfile('source.txt','distination.txt')
# Out:
# 'distination.txt'

# %%
## Data serialization
import json
data={'name':'dishu','age':25}

json_str=json.dumps(data)
print(json_str)

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "dishu", "age": 25}
# {'name': 'dishu', 'age': 25}
# <class 'dict'>

# %%
## csv:
import csv
with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['dishu','21'])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['dishu', '21']

# %%
## date time:
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-06-28 18:23:47.857482
# 2026-06-27 18:23:47.857482

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1782651329.0602653
# 1782651331.0611653

# %%
## regular expersion:
import re 
pattern=r'\d+'
text='this are 123  apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
