# %%
import pandas as pd 
import requests

# %%
requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
# Out:
# <Response [200]>

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#    'genre_ids': [35, 10749],
#    'id': 1632181,
#    'title': 'Accidental Partners',
#    'original_language': 'es',
#    'original_title': 'Socias por accidente',
#    'overview': 'Two women discover they were both scammed by the same man (who also got them pregnant). They form an alliance to take revenge.',
#    'popularity': 19.7326,
#    'poster_path': '/sr1Yoj6XLPTWYcbDoBy67xivW4I.jpg',
#    'release_date': '2026-03-12',
#    'softcore': False,
#    'video': False,
#    'vote_average': 9.056,
#    'vote_count': 301},
#   {'adult': False,
#    'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#    'genre_ids': [12, 16, 10751, 14],
#    'id': 1007757,
#    'title': 'Swapped',
#    'original_language': 'en',
#    'original_title': 'Swapped',
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#   'genre_ids': [35, 10749],
#   'id': 1632181,
#   'title': 'Accidental Partners',
#   'original_language': 'es',
#   'original_title': 'Socias por accidente',
#   'overview': 'Two women discover they were both scammed by the same man (who also got them pregnant). They form an alliance to take revenge.',
#   'popularity': 19.7326,
#   'poster_path': '/sr1Yoj6XLPTWYcbDoBy67xivW4I.jpg',
#   'release_date': '2026-03-12',
#   'softcore': False,
#   'video': False,
#   'vote_average': 9.056,
#   'vote_count': 301},
#  {'adult': False,
#   'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#   'genre_ids': [12, 16, 10751, 14],
#   'id': 1007757,
#   'title': 'Swapped',
#   'original_language': 'en',
#   'original_title': 'Swapped',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path            genre_ids       id  \
# 0   False  /iCML6fBe3X0y06P33bM7dyYXPKZ.jpg          [35, 10749]  1632181
# 1   False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
# 2   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg             [18, 80]      278
# 3   False  /ufSwlnECLoUbBjPrFqEQcWBzHwc.jpg          [10402, 18]   936075
# 4   False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg             [18, 80]      238
# 5   False  /8Tfys3mDZVp4tNoH2ktm06a0Tau.jpg            [878, 12]   687163
# 6   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg             [18, 80]      240
# 7   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg      [18, 36, 10752]      424
# 8   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                 [18]      389
# 9   False  /vpuPY4UziUCxv7gYYoaZQ3LX7to.jpg             [28, 53]  1383731
# 10  False  /bVGHSe47W6oCQL1Q88pvRAet51A.jpg           [18, 9648]  1330021
# 11  False  /dyJvKsNs2KP8qQnAXbRwDjblViy.jpg      [16, 10751, 14]      129
# ...

# %%
pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','vote_average','vote_count','popularity']]
# Out:
#          id                                          title  \
# 0   1632181                            Accidental Partners
# 1   1007757                                        Swapped
# 2       278                       The Shawshank Redemption
# 3    936075                                        Michael
# 4       238                                  The Godfather
# 5    687163                              Project Hail Mary
# 6       240                          The Godfather Part II
# 7       424                               Schindler's List
# 8       389                                   12 Angry Men
# 9   1383731                                      Protector
# 10  1330021                    Remarkably Bright Creatures
# 11      129                                  Spirited Away
# 12      155                                The Dark Knight
# 13    19404                    Dilwale Dulhania Le Jayenge
# 14      497                                 The Green Mile
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','vote_average','vote_count','popularity']]

# %%
df.head()
# Out:
#         id                     title  \
# 0  1632181       Accidental Partners
# 1  1007757                   Swapped
# 2      278  The Shawshank Redemption
# 3   936075                   Michael
# 4      238             The Godfather
#
#                                             overview release_date  \
# 0  Two women discover they were both scammed by t...   2026-03-12
# 1  A small woodland creature and a majestic bird,...   2026-05-01
# 2  Imprisoned in the 1940s for the double murder ...   1994-09-23
# 3  The story of Michael Jackson, one of the most ...   2026-04-22
# 4  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
#
#    vote_average  vote_count  popularity
# 0         9.056         301     19.7326
# 1         8.917        1912     86.1168
# 2         8.725       30740    155.0866
# 3         8.706        3425    165.3574
# 4         8.687       23145     38.8307

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17616\2968228005.py in ?()
#       1 for i in range(1,429):
#       2     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
#       3     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# ----> 4     df = df.append(temp_df,ignore_index=True)
#       5
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# ...
