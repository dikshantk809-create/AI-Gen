# %% [markdown]
# #### Variables

# %% [markdown]
# Variables are fundamental elements in programing used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explict declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.

# %%
a=100

# %%
## declaring and assigning variables in python
age=21
height=5.9
name="Dikshant"
is_student=True
# Printing the variables
print("age:", age)
print("height:", height)
print("name:", name)
print("is_student:", is_student)
# Out:
# age: 21
# height: 5.9
# name: Dikshant
# is_student: True

# %%
# Naming Conventions in Python:
# Variable  name should be descriptive
# They must start with a letter or an "_" and contains letter,names,digits or underscores
# They are case-sensitive
# Avoid using Python reserved keywords as variable names
# Examples of valid variable names:
first_name = "Dikshant"
last_name = "aggarwal"

# %%
# Invalid variable names (uncommenting these will cause errors):
 1name = "Dikshant"  # Starts with a digit
# Out:
#   Cell In[3], line 2
#     1name = "Dikshant"  # Starts with a digit
#     ^
# IndentationError: unexpected indent

# %%
## Case Sensitivity in Variable Names:
name="Dikshant"
Name="dishu"

name==Name  # This will return False
# Out:
# False

# %%
# Understanding variable types in Python:
## Python is dynamically typed, meaning you don't need to declare variable types explicitly. The interpreter infers the type based on the assigned value.
age = 25               # Integer
height = 5.9          # Float
name = "Dikshant"     # String
is_student = True     # Boolean
print(type(age))        # <class 'int'>
# Out:
# <class 'int'>

# %%
print(type(name))       # <class 'str'>
# Out:
# <class 'str'>

# %%
## Type Checking and conversion:
type(height)  # <class 'float'>
# Out:
# float

# %%
age=21
print(type(age))  # <class 'int'>
#type conversion
age_str=str(age)
print(age_str)  # '21'
print(type(age_str))  # <class 'str'>
# Out:
# <class 'int'>
# 21
# <class 'str'>

# %%
age="21"
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name="Dikshant"
int(name)  # This will raise a ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 name="Dikshant"
# ----> 2 int(name)  # This will raise a ValueError
#
# ValueError: invalid literal for int() with base 10: 'Dikshant'

# %%
height=5.9
type(int(height))  # This will return 5
int(height)  # This will return 5
# Out:
# 5

# %%
float(height)  # This will return 5.9
# Out:
# 5.9

# %%
# Dynamic Typing in Python:
# Python allows you to change the type of a variable by reassigning it to a different type of value.
var=10 #int
print(var,type(var))

var="hello" #str
print(var,type(var))

var=5.5 #float
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 5.5 <class 'float'>

# %%
# input() Function:
age=input("Enter your age: ")  # input() returns a string
print("Your age is:", age)
# Out:
# Your age is: 22

# %%
# Simple Calculator using variables and input():
num1=input("Enter first number: ")
num2=input("Enter second number: ") 
sum=float(num1)+float(num2)
diff=float(num1)-float(num2)
product=float(num1)*float(num2)
qotient=float(num1)/float(num2)
print("The sum of",num1,"and",num2,"is:",sum)               
print("The difference of",num1,"and",num2,"is:",diff)
print("The product of",num1,"and",num2,"is:",product)
print("The quotient of",num1,"and",num2,"is:",qotient)
# Out:
# The sum of 1 and 4 is: 5.0
# The difference of 1 and 4 is: -3.0
# The product of 1 and 4 is: 4.0
# The quotient of 1 and 4 is: 0.25
